# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, cross_val_score

# %%
df = pd.read_csv('train.csv')

# %%
pd.options.display.max_rows = 99
pd.options.display.max_columns = 99

# %%
df.shape
# Out:
# (2051, 81)

# %%
df[df['Mas Vnr Area'].isna()] #Masonry Veneer is a strong indicator of housing quality, so it's in our interest to drop these rows or rename them to None/0 to run them
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 22    2393  528142010           60        RL         103.0     12867   Pave
# 41    2383  528110050           20        RL         107.0     13891   Pave
# 86     539  531371050           20        RL          67.0     10083   Pave
# 212    518  528458020           20        FV          90.0      7993   Pave
# 276   2824  908130020           20        RL          75.0      8050   Pave
# 338   1800  528458150           60        FV         112.0     12217   Pave
# 431   1455  907251090           60        RL          75.0      9473   Pave
# 451   1120  528439010           20        RL          87.0     10037   Pave
# 591   1841  533208040          120        FV          35.0      4274   Pave
# 844   1840  533208030          120        FV          30.0      5330   Pave
# 913   2230  909475070           20        RL           NaN     32668   Pave
# ...

# %%
df.dropna(subset=['Bsmt Full Bath', 'Bsmt Half Bath', 'Garage Cars', 'Garage Area', 'BsmtFin SF 1', 'Mas Vnr Area', 'Mas Vnr Type'], inplace = True)
#these have small sets of values with null values that can easily be afforded to be dropped for cleaner data

# %%
#df.dropna(subset=['Mas Vnr Type', 'Mas Vnr Area'], inplace = True)

# %%
df[df['Garage Type'].isna()].head() # These are very likely 0 values because there is no Garage
# Out:
#        Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 28   2243  911103060          190   C (all)          75.0      8250   Pave
# 53    330  923226250          160        RM          21.0      1476   Pave
# 65   2278  923202134           20        RL          70.0      8402   Pave
# 79   2235  910201050           50        RM          50.0      7288   Pave
# 101  2084  905476170           30        RL          58.0      9098   Pave
#
#     Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 28    NaN       Reg          Lvl    AllPub     Inside        Gtl       IDOTRR
# 53    NaN       Reg          Lvl    AllPub     Inside        Gtl      MeadowV
# 65    NaN       Reg          Lvl    AllPub     Inside        Gtl      Mitchel
# 79    NaN       Reg          Lvl    AllPub     Inside        Gtl       IDOTRR
# 101   NaN       IR1          Lvl    AllPub     Inside        Gtl      Edwards
#
# ...

# %%
df[df['Lot Frontage'].isna()].head()  #These are missing values - most of the Lot Area values seem listed.  Could remove these whole values
# Out:
#       Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0    109  533352170           60        RL           NaN     13517   Pave
# 7    145  535154050           20        RL           NaN     12160   Pave
# 8   1942  535353130           20        RL           NaN     15783   Pave
# 23    12  527165230           20        RL           NaN      7980   Pave
# 27  1534  909277040           50        RL           NaN     11700   Pave
#
#    Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0    NaN       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 7    NaN       IR1          Lvl    AllPub     Inside        Gtl        NAmes
# 8    NaN       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 23   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 27  Grvl       IR1          HLS    AllPub     Inside        Mod      Crawfor
#
# ...

# %%
#df[df['Garage Type'].map(replace('NaN', 'Na'))

# %%
df.dropna(axis = 1, thresh = 500, inplace = True)

# %%
df.isnull().sum()
# Out:
# Id                   0
# PID                  0
# MS SubClass          0
# MS Zoning            0
# Lot Frontage       324
# Lot Area             0
# Street               0
# Lot Shape            0
# Land Contour         0
# Utilities            0
# Lot Config           0
# Land Slope           0
# Neighborhood         0
# Condition 1          0
# Condition 2          0
# Bldg Type            0
# House Style          0
# Overall Qual         0
# Overall Cond         0
# Year Built           0
# Year Remod/Add       0
# Roof Style           0
# Roof Matl            0
# Exterior 1st         0
# Exterior 2nd         0
# Mas Vnr Type         0
# Mas Vnr Area         0
# Exter Qual           0
# Exter Cond           0
# Foundation           0
# Bsmt Qual           53
# Bsmt Cond           53
# Bsmt Exposure       56
# BsmtFin Type 1      53
# BsmtFin SF 1         0
# BsmtFin Type 2      54
# BsmtFin SF 2         0
# Bsmt Unf SF          0
# Total Bsmt SF        0
# Heating              0
# ...

# %%
#df.drop(columns=['Fireplace Qu' , 'Lot Frontage'], inplace = True) #998 missing values is pretty big and could mean this column  is biased)

# %% [markdown]
# <h1>FEATURE ENGINEERING</h1>

# %%
#DUMMIES 
df = pd.get_dummies(df, columns=['Central Air'])

df = pd.get_dummies(df, columns = ['Exter Qual'])

df = pd.get_dummies(df, columns = ['Heating QC'])

df = pd.get_dummies(df, columns=['Paved Drive'])

# %%
df['Total_Bldg_SF'] = df['Total Bsmt SF'] + df['1st Flr SF'] + df['2nd Flr SF'] + df['Open Porch SF']  

df['Garage_Interaction'] = df['Garage Area']*df['Garage Cars']

df['Year_Interaction'] = df['Year Built'] * df['Year Remod/Add']

df['Bath_Interaction'] = df['Full Bath'] * df['Half Bath']

#df['Conditioning_Interaction'] = df['Heating QC_Ex'] * ['Central Air_Y'] huh that didn't work...

# %%
holdout = pd.read_csv('test.csv') # YOU MUST DO SEPARATE CLEANUP ON THE HOLDOUT

# %%
holdout.dropna(subset=['Bsmt Full Bath', 'Bsmt Half Bath', 'Garage Cars', 'Garage Area', 'BsmtFin SF 1'], inplace = True)
holdout.dropna(axis = 1, thresh = 500, inplace = True)

# %%
#df['Wood Deck SF'] has errors in the holdout set...I guess I need to either make these zeros or not include them...
# same as the beneer part

# %%
holdout['Year_Interaction'] = holdout['Year Built'] * holdout['Year Remod/Add']

holdout['Garage_Interaction'] = holdout['Garage Area']*holdout['Garage Cars']


holdout['Bath_Interaction'] = holdout['Full Bath'] * holdout['Half Bath']

#holdout['Conditioning Interaction'] = holdout['Heating QC_Ex'] * holdout['Central Air_Y']

holdout['Total_Bldg_SF'] = holdout['Total Bsmt SF'] + holdout['1st Flr SF'] + holdout['2nd Flr SF'] + holdout['Open Porch SF']

# %%
holdout.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4       IR1          Lvl    AllPub     Inside        Gtl        NAmes
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# ...

# %%
def holdout_aight():
    print(holdout.shape)
    print(holdout.isnull().sum())

# %%
holdout_aight()
# Out:
# (879, 79)
# Id                      0
# PID                     0
# MS SubClass             0
# MS Zoning               0
# Lot Frontage          160
# Lot Area                0
# Street                  0
# Lot Shape               0
# Land Contour            0
# Utilities               0
# Lot Config              0
# Land Slope              0
# Neighborhood            0
# Condition 1             0
# Condition 2             0
# Bldg Type               0
# House Style             0
# Overall Qual            0
# Overall Cond            0
# Year Built              0
# Year Remod/Add          0
# Roof Style              0
# Roof Matl               0
# Exterior 1st            0
# Exterior 2nd            0
# Mas Vnr Type            1
# Mas Vnr Area            1
# Exter Qual              0
# Exter Cond              0
# Foundation              0
# Bsmt Qual              25
# Bsmt Cond              25
# Bsmt Exposure          25
# BsmtFin Type 1         25
# BsmtFin SF 1            0
# ...

# %%
holdout = pd.get_dummies(holdout, columns=['Central Air'])

# %%
holdout = pd.get_dummies(holdout, columns =['Paved Drive'])

# %%
holdout = pd.get_dummies(holdout, columns = ['Heating QC'])

# %%
#holdout = pd.get_dummies(holdout, columns = ['Utilities']) not as fruitful as I had hoped

# %%
holdout = pd.get_dummies(holdout, columns = ['Exter Qual'])

# %%
#holdout = pd.get_dummies(holdout, columns = ['Sale Type'])

# %%
holdout.drop(columns=['Garage Area', 'Garage Cars', 'Central Air_N', 'Paved Drive_P', 'Exter Qual_Fa'], inplace = True)

# %%
holdout.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4       IR1          Lvl    AllPub     Inside        Gtl        NAmes
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# ...

# %%
df['Garage_Interaction'] = df['Garage Area']*df['Garage Cars']
df['Year_Interaction'] = df['Year Built'] * df['Year Remod/Add']
df['Bath_Interaction'] = df['Full Bath'] * df['Half Bath']

# %%
df.drop(columns=['Garage Area', 'Garage Cars', 'Central Air_N', 'Paved Drive_P', 'Heating QC_Po', 'Exter Qual_Fa',], inplace = True)

# %%
#removing wooden deck here too
df['Total_Bldg_SF'] = df['Total Bsmt SF'] + df['1st Flr SF'] + df['2nd Flr SF'] + df['Open Porch SF']

# %%
X = df[['Overall Qual', 'Total_Bldg_SF', 'Garage_Interaction', 'Year_Interaction',
        'Full Bath', 'Bath_Interaction', 'Fireplaces', 'Central Air_Y', 
        'Paved Drive_Y', 'Paved Drive_N', 'Heating QC_Ex', 'Heating QC_Fa', 'Heating QC_Gd', 'Heating QC_TA',
        'Exter Qual_Ex', 'Exter Qual_TA']]

# %%
df.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  109  533352170           60        RL           NaN     13517   Pave
# 1  544  531379050           60        RL          43.0     11492   Pave
# 2  153  535304180           20        RL          68.0      7922   Pave
# 3  318  916386060           60        RL          73.0      9802   Pave
# 4  255  906425045           50        RL          82.0     14235   Pave
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# ...

# %%
#X = df[['Overall Qual', 'Gr Liv Area', 'Garage_Interaction', 'Total Bsmt SF', '1st Flr SF', 'Year Built', 'Year Remod/Add', 'Full Bath', 'TotRms AbvGrd', 'Fireplaces', 'PID', 'Enclosed Porch', 'Open Porch SF', 
#       'Wood Deck SF', 'Half Bath', '2nd Flr SF', 'Mas Vnr Area']] Before swapping SF variables for Total_Bldg_SF

# %%
plt.subplots(figsize = (14, 14))
sns.heatmap(df.corr()[['Overall Qual']].sort_values('Overall Qual'), annot=True)

# %%
plt.subplots(figsize = (15, 15))
sns.heatmap(df.corr()[['SalePrice']].sort_values('SalePrice'), annot= True)
plt.title("Designed and Cleaned Correlations For Ames Sale Prices ")
# Out:
# Text(0.5, 1.0, 'Designed and Cleaned Correlations For Ames Sale Prices ')

# %%
#df = df.rename(columns={"Overall Qual": "Overall_Quality", "Mas Vnr Area": "Masonry veneer area", 
#                        "TotRms AbvGrd": "Total Rooms Above Ground", "Exter Qual_Ex":"Excellent Exterior Quality", "Exter Qual_TA": "Typical Exterior Quality", 
#                        "Heating QC_Ex" :" Excellent Heating Quality", "Heating QC_Fa":"Fair Heating Quality", "Heating QC_TA":"Typical Heating Quality", "PID": "Parcel ID Number", 
#                       "Central Air_Y": "YES Central Air", "Central Air_N": "NO Central Air", "Paved Drive_Y":"YES Paved Driveway", "Paved Drive_N":"NO Paved Driveway"})

#Used for presentation readibility only

# %%
X.isna().sum()

# %%
#X = df.loc[:, ['Gr Liv Area', 'Year Built', 'Full Bath']]
y = df['SalePrice']

# %%
X.shape

# %%
X
# Out:
#       Overall Qual  Total_Bldg_SF  Garage_Interaction  Year_Interaction  \
# 0                6         2248.0               950.0           3961880
# 1                7         3109.0              1118.0           3986012
# 2                5         2166.0               246.0           3919671
# 3                5         1828.0               800.0           4026042
# 4                6         2180.0               968.0           3786700
# 5                6         3405.0              1156.0           3935932
# 6                6         1663.0              1050.0           4022030
# 7                5         2376.0              1062.0           3837681
# 8                5         2172.0               420.0           3810304
# 9                5         3120.0              1008.0           3876961
# 10               6         1470.0               264.0           3884841
# 11               7         2474.0              1264.0           4020025
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
ss = StandardScaler()
ss.fit(X_train) 
X_train = ss.transform(X_train)
X_test = ss.transform(X_test)  #Is this ok??  Do I need the unscaled training data after this?
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.

# %%
holdout.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4       IR1          Lvl    AllPub     Inside        Gtl        NAmes
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# ...

# %%
holdout_scaled = ss.transform(holdout[['Overall Qual', 'Total_Bldg_SF', 'Garage_Interaction', 'Year_Interaction',
        'Full Bath', 'Bath_Interaction', 'Fireplaces', 'Central Air_Y', 
        'Paved Drive_Y', 'Paved Drive_N', 'Heating QC_Ex', 'Heating QC_Fa', 'Heating QC_Gd', 'Heating QC_TA',
        'Exter Qual_Ex', 'Exter Qual_TA']])
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.

# %%
holdout_scaled.shape
# Out:
# (879, 16)

# %%
holdout.shape
# Out:
# (879, 83)

# %%
#plt.hist(df['Exter Qual'])
#plt.title("Negative Relation of 'Typical' Exterior quality on Sales Prices in Ames")
#plt.xlabel("Exterior q")
#plt.ylabel("Sale Prices")
#plt.show()

# %%
plt.scatter(df['Garage_Interaction'], y)
plt.title("Relation of Garage size and layout with Sales Prices in Ames")
plt.xlabel("Garage Interaction")
plt.ylabel("Sale Prices")
plt.show()

# %%
#plt.subplots(figsize = (40, 40))
#sns.heatmap(df.corr(), annot = True)

# %%
#plt.subplots(20, 20)
#sns.heatmap(X.corr(), annot = True)

# %%
print('X training data shape is', X_train.shape)
print('X testing data shape is', X_test.shape)
print('y training data shape is', y_train.shape)
print('y testing data shape is', y_test.shape)
print('holdout scaled shape is', holdout_scaled.shape)
# Out:
# X training data shape is (1519, 16)
# X testing data shape is (507, 16)
# y training data shape is (1519,)
# y testing data shape is (507,)
# holdout scaled shape is (879, 16)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
cv_scores = cross_val_score(lr, X_train, y_train, cv=8)
preds = lr.predict(holdout_scaled)

# %%
preds[:10]
# Out:
# array([147886.37537194, 191639.74743689, 204100.24596011, 125267.41534175,
#        198414.10381132,  91280.21500686, 103142.96443662, 138129.36473643,
#        210974.44074844, 183312.54718296])

# %%
sub = holdout[['Id']]
sub['SalePrice'] = preds
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
sub.shape
# Out:
# (879, 2)

# %%
print('cv score', cross_val_score(lr, X_train, y_train, cv=10).mean())
print('train score', lr.score(X_train, y_train))
print('test score', lr.score(X_test,y_test))

# %%
#Removing Gr living area at this point hardly changes my model

# %% [markdown]
# <h1>Regularize It! </h1>

# %%
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression, RidgeCV, LassoCV, ElasticNetCV

# %%
ridge = RidgeCV(cv=10)

r_alphas = np.logspace(0, 100, 100)

ridge_model = ridge

ridge.fit(X_train, y_train)

ridge_model.alpha_

preds = ridge.predict(holdout_scaled)

# %%
sub = holdout[['Id']]
sub['SalePrice'] = preds
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
print('Ridge score', cross_val_score(ridge, X_train, y_train, cv=10).mean())
print('train score', ridge.score(X_train, y_train))
print('test score', ridge.score(X_test,y_test))
# Out:
# Ridge score 0.7973555627219951
# train score 0.8094005699365554
# test score 0.8470859447982452

# %%
#Ridge seems to be doing best, since I did my best to limit colinearity!

# %%
lasso.alpha_
# Out:
# 1118.888888888889

# %%
print('Lasso score', cross_val_score(lasso, X_train, y_train, cv=10).mean())
print('train score', lasso.score(X_train, y_train))
print('test score', lasso.score(X_test,y_test))
# Out:
# Lasso score 0.7978262724368601
# train score 0.8065780080681264
# test score 0.8500897387909961

# %%
sub = holdout[['Id']]
sub['SalePrice'] = preds
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
preds.mean()
# Out:
# 178116.241729546

# %%
#print('cv score', cross_val_score(lr, X_train, y_train, cv=10).mean())
#print('train score', lr.score(X_train, y_train))
#print('test score', lr.score(X_test,y_test))

# %%
sub.to_csv('kaggle_sub_13', index=False)
