# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
# ...

# %%
df.shape
# Out:
# (2051, 81)

# %%
holdout = pd.read_csv('test.csv')

# %%
holdout.shape
# Out:
# (879, 80)

# %%
pd.options.display.max_columns = 85 #To remove ellipses in columns on any display!

# %%
pd.options.display.max_rows = 100

# %%
df.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
# ...

# %%
df.shape
# Out:
# (2051, 81)

# %%
df.drop(columns=['Pool QC', 'Fence', 'Alley', 'Fireplace Qu'], inplace = True)

# %%
df.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  109  533352170           60        RL           NaN     13517   Pave
# 1  544  531379050           60        RL          43.0     11492   Pave
# 2  153  535304180           20        RL          68.0      7922   Pave
# 3  318  916386060           60        RL          73.0      9802   Pave
# 4  255  906425045           50        RL          82.0     14235   Pave
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# ...

# %%
df.dtypes #KitchenQual could be converted to ints, as is with all qual variables on a scale
# Out:
# Id                   int64
# PID                  int64
# MS SubClass          int64
# MS Zoning           object
# Lot Frontage       float64
# Lot Area             int64
# Street              object
# Lot Shape           object
# Land Contour        object
# Utilities           object
# Lot Config          object
# Land Slope          object
# Neighborhood        object
# Condition 1         object
# Condition 2         object
# Bldg Type           object
# House Style         object
# Overall Qual         int64
# Overall Cond         int64
# Year Built           int64
# Year Remod/Add       int64
# Roof Style          object
# Roof Matl           object
# Exterior 1st        object
# Exterior 2nd        object
# Mas Vnr Type        object
# Mas Vnr Area       float64
# Exter Qual          object
# Exter Cond          object
# Foundation          object
# Bsmt Qual           object
# Bsmt Cond           object
# Bsmt Exposure       object
# BsmtFin Type 1      object
# ...

# %%
X = df.loc[:, ['Gr Liv Area', 'Year Built', 'Full Bath', '']]
y = df['SalePrice']

# %%
X.head()
# Out:
#    Gr Liv Area  Year Built  Full Bath
# 0         1479        1976          2 NaN
# 1         2122        1996          2 NaN
# 2         1057        1953          1 NaN
# 3         1444        2006          2 NaN
# 4         1445        1900          2 NaN

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 4 columns):
# Gr Liv Area    2051 non-null int64
# Year Built     2051 non-null int64
# Full Bath      2051 non-null int64
#                0 non-null float64
# dtypes: float64(1), int64(3)
# memory usage: 64.2 KB

# %%
df.corr()[['SalePrice']].sort_values('SalePrice')
# Out:
#                  SalePrice
# PID              -0.255052
# Enclosed Porch   -0.135656
# Kitchen AbvGr    -0.125444
# Overall Cond     -0.097019
# MS SubClass      -0.087335
# Id               -0.051398
# Bsmt Half Bath   -0.045328
# Low Qual Fin SF  -0.041594
# Yr Sold          -0.015203
# Misc Val         -0.007375
# BsmtFin SF 2      0.016255
# Pool Area         0.023106
# Mo Sold           0.032735
# 3Ssn Porch        0.048732
# Screen Porch      0.134581
# Bedroom AbvGr     0.137067
# Bsmt Unf SF       0.190210
# 2nd Flr SF        0.248452
# Half Bath         0.283001
# Bsmt Full Bath    0.283662
# Lot Area          0.296566
# Wood Deck SF      0.326490
# Open Porch SF     0.333476
# Lot Frontage      0.341842
# BsmtFin SF 1      0.423519
# Fireplaces        0.471093
# TotRms AbvGrd     0.504014
# Mas Vnr Area      0.512230
# Garage Yr Blt     0.533922
# Full Bath         0.537969
# Year Remod/Add    0.550370
# Year Built        0.571849
# 1st Flr SF        0.618486
# ...

# %%
df.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  109  533352170           60        RL           NaN     13517   Pave
# 1  544  531379050           60        RL          43.0     11492   Pave
# 2  153  535304180           20        RL          68.0      7922   Pave
# 3  318  916386060           60        RL          73.0      9802   Pave
# 4  255  906425045           50        RL          82.0     14235   Pave
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# ...

# %%
dfkeyvalues = df.loc[:, 'Gr Liv Area', 'Year Built' 'Total Basement SF']
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-59-c19e157ecc35> in <module>
# ----> 1 dfkeyvalues = df.loc[:, 'Gr Liv Area', 'Year Built' 'Total Basement SF']
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     871
#     872         # no multi-index, so validate all of the indexers
# --> 873         self._has_valid_tuple(tup)
#     874
#     875         # ugly hack for GH #836
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
# ...

# %%
plt.subplots(figsize = (40, 40))
sns.heatmap(df.corr(), annot = True)

# %%
plt.subplots(figsize = (12, 12))
sns.heatmap(df.corr()[['SalePrice']].sort_values('SalePrice'), annot= True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
X_train.shape
# Out:
# (1538, 4)

# %%
X_test.shape
# Out:
# (513, 4)

# %%
y_train.shape
# Out:
# (1538,)

# %%
y_test.shape
# Out:
# (513,)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
preds = lr.predict(holdout[['Overall Qual', 'Gr Liv Area', 'Year Built', 'Full Bath']])

# %%
X_test.shape
# Out:
# (513, 4)

# %%
preds[:10]
# Out:
# array([177750.05367692, 255091.94060625, 118440.89000677, 166006.4705154 ,
#        133885.33804488, 197917.89298404, 168140.61199172, 129953.85966569,
#        109547.95614526, 191405.0131572 ])

# %%
preds.shape
# Out:
# (2051,)

# %%
sub = holdout[['Id']]

# %%
sub.head()
# Out:
#      Id
# 0  2658
# 1  2718
# 2  2414
# 3  1989
# 4   625

# %%
sub['SalePrice'] = preds
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sub.head()
# Out:
#      Id      SalePrice
# 0  2658  169677.638305
# 1  2718  182893.239768
# 2  2414  221310.479902
# 3  1989   96384.381392
# 4   625  171094.674774

# %%
sub.shape
# Out:
# (879, 2)

# %%
sub.to_csv('kaggle_sub_3_190318.csv', index=False)
